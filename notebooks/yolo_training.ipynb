# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/BDD_YOLO

# %%
# !cp -r "/content/drive/MyDrive/BDD_YOLO" /content/

# %%
# !ls /content/BDD_YOLO
# Out:
# data.yaml  images  labels

# %%
# !ls /content/BDD_YOLO
# Out:
# data.yaml  images  labels

# %%
data_yaml = """
path: /content/BDD_YOLO
train: images/val
val: images/val

nc: 1
names: ['pedestrian']
"""

with open("/content/BDD_YOLO/data.yaml", "w") as f:
    f.write(data_yaml)

# %%
# !rm -f /content/BDD_YOLO/labels/val.cache

# %%
# !rm -f "/content/drive/MyDrive/BDD_YOLO/labels/val.cache"

# %%
# !cat /content/BDD_YOLO/data.yaml
# Out:
# path: /content/BDD_YOLO
# train: images/val
# val: images/val
#
# nc: 1
# names: ['pedestrian']

# %%
# !rm -rf /content/BDD_YOLO

# %%
# !mkdir -p /content/BDD_YOLO/images/val
# !mkdir -p /content/BDD_YOLO/labels/val

# %%
# !rsync -av "/content/drive/MyDrive/BDD_YOLO/images/val/" /content/BDD_YOLO/images/val/
# Out:
# sending incremental file list
# ./
# b1c66a42-6f7d68ca.jpg
# b1ca2e5d-84cf9134.jpg
# b1cd1e94-549d0bfe.jpg
# b1ceb32e-3f481b43.jpg
# b1ceb32e-51852abe.jpg
# b1ceb32e-a106591d.jpg
# b1d0a191-03dcecc2.jpg
# b1d0a191-06deb55d.jpg
# b1d0a191-28f0e779.jpg
# b1d0a191-2ed2269e.jpg
# b1d0a191-5490450b.jpg
# b1d0a191-65deaeef.jpg
# b1d0a191-de8948f6.jpg
# b1d10d08-da110fcb.jpg
# b1d22ed6-f1cac061.jpg
# b1d4b62c-d9805029.jpg
# b1d7b3ac-0bdb47dc.jpg
# b1d7b3ac-995f9d8a.jpg
# b1d968b9-563405f4.jpg
# b1d968b9-ce42734f.jpg
# b1d9e136-6c94ea3f.jpg
# b1d9e136-9ab25cb3.jpg
# b1dce572-c6a8cb5e.jpg
# b1dd58c1-8b546ba7.jpg
# b1df722f-5bcc3db7.jpg
# b1e0c01d-dd9e6e2f.jpg
# b1e1a7b8-65ec7612.jpg
# b1e3e9f5-92377424.jpg
# b1e9ee0e-67e26f2e.jpg
# b1ebfc3c-740ec84a.jpg
# b1ebfc3c-cc9c2bb8.jpg
# b1f022d3-3774de8b.jpg
# b1f0efd9-e900c6e5.jpg
# b1f20aa0-3401c3bf.jpg
# b1f20aa0-50213047.jpg
# b1f4491b-16256d7c.jpg
# b1f4491b-33824f31.jpg
# b1f4491b-97465266.jpg
# b1f4491b-9958bd99.jpg
# b1f4491b-cf446195.jpg
# ...

# %%
# !rsync -av "/content/drive/MyDrive/BDD_YOLO/labels/val/" /content/BDD_YOLO/labels/val/
# Out:
# sending incremental file list
# ./
# b1c66a42-6f7d68ca.txt
# b1ca2e5d-84cf9134.txt
# b1cd1e94-549d0bfe.txt
# b1ceb32e-3f481b43.txt
# b1ceb32e-51852abe.txt
# b1ceb32e-a106591d.txt
# b1d0a191-03dcecc2.txt
# b1d0a191-06deb55d.txt
# b1d0a191-28f0e779.txt
# b1d0a191-2ed2269e.txt
# b1d0a191-5490450b.txt
# b1d0a191-65deaeef.txt
# b1d0a191-de8948f6.txt
# b1d10d08-da110fcb.txt
# b1d22ed6-f1cac061.txt
# b1d4b62c-d9805029.txt
# b1d7b3ac-0bdb47dc.txt
# b1d7b3ac-995f9d8a.txt
# b1d968b9-563405f4.txt
# b1d968b9-ce42734f.txt
# b1d9e136-6c94ea3f.txt
# b1d9e136-9ab25cb3.txt
# b1dce572-c6a8cb5e.txt
# b1dd58c1-8b546ba7.txt
# b1df722f-5bcc3db7.txt
# b1e0c01d-dd9e6e2f.txt
# b1e1a7b8-65ec7612.txt
# b1e3e9f5-92377424.txt
# b1e9ee0e-67e26f2e.txt
# b1ebfc3c-740ec84a.txt
# b1ebfc3c-cc9c2bb8.txt
# b1f022d3-3774de8b.txt
# b1f0efd9-e900c6e5.txt
# b1f20aa0-3401c3bf.txt
# b1f20aa0-50213047.txt
# b1f4491b-16256d7c.txt
# b1f4491b-33824f31.txt
# b1f4491b-97465266.txt
# b1f4491b-9958bd99.txt
# b1f4491b-cf446195.txt
# ...

# %%
# %%writefile /content/BDD_YOLO/data.yaml
# path: /content/BDD_YOLO
# train: images/val
# val: images/val
#
# nc: 1
# names: ['pedestrian']
# Out:
# Overwriting /content/BDD_YOLO/data.yaml

# %%
# !ls /content/BDD_YOLO/images/val | wc -l
# !ls /content/BDD_YOLO/labels/val | wc -l
# Out:
# 3400
# 3400

# %%
# !rm -f /content/BDD_YOLO/labels/val.cache

# %%
# !yolo train model=yolov8n.pt data=/content/BDD_YOLO/data.yaml epochs=30 imgsz=640 cache=disk workers=4
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# **FINAL WORK**

# %%
# !rm -rf /content/BDD_YOLO

# %%
# !mkdir -p /content/BDD_YOLO/images/val
# !mkdir -p /content/BDD_YOLO/labels/val

# %%
# !cp -r /content/drive/MyDrive/BDD_YOLO/images/val/* /content/BDD_YOLO/images/val/
# !cp -r /content/drive/MyDrive/BDD_YOLO/labels/val/* /content/BDD_YOLO/labels/val/

# %%
# !ls /content/BDD_YOLO/images/val | wc -l
# !ls /content/BDD_YOLO/labels/val | wc -l
# Out:
# 3400
# 3400

# %%
# %%writefile /content/BDD_YOLO/data.yaml
# path: /content/BDD_YOLO
# train: images/val
# val: images/val
#
# nc: 1
# names: ['pedestrian']
# Out:
# Writing /content/BDD_YOLO/data.yaml

# %%
# !rm -f /content/BDD_YOLO/labels/val.cache

# %%
# !yolo train model=yolov8n.pt data=/content/BDD_YOLO/data.yaml epochs=30 imgsz=640 cache=disk workers=4
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !mkdir -p /content/drive/MyDrive/ADAS_MODELS
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/ADAS_MODELS/
# Out:
# cp: cannot stat '/content/runs/detect/train/weights/best.pt': No such file or directory

# %%
# !cp /content/runs/detect/train2/weights/best.pt /content/drive/MyDrive/ADAS_MODELS/

# %%
# !ls /content/runs/detect/
# Out:
# train  train2

# %%
# !ls /content/runs/detect/train2/weights
# Out:
# best.pt  last.pt

# %%
# !mkdir -p /content/drive/MyDrive/ADAS_MODELS
# !cp /content/runs/detect/train2/weights/best.pt /content/drive/MyDrive/ADAS_MODELS/

# %%
# !ls /content/drive/MyDrive/ADAS_MODELS
# Out:
# best.pt

# %%
from google.colab import files
files.download('/content/runs/detect/train2/weights/best.pt')

# %%
# !mkdir -p /content/drive/MyDrive/ADAS_RUN_RESULTS
# !cp -r /content/runs/detect/train2 /content/drive/MyDrive/ADAS_RUN_RESULTS/

# %%
# !ls /content/drive/MyDrive/ADAS_RUN_RESULTS
# Out:
# train2

# %%
# !yolo predict model=/content/drive/MyDrive/ADAS_MODELS/best.pt source=/content/BDD_YOLO/images/val save=True
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/3400 /content/BDD_YOLO/images/val/b1c66a42-6f7d68ca.jpg: 384x640 1 pedestrian, 64.7ms
# image 2/3400 /content/BDD_YOLO/images/val/b1ca2e5d-84cf9134.jpg: 384x640 7 pedestrians, 6.3ms
# image 3/3400 /content/BDD_YOLO/images/val/b1cd1e94-549d0bfe.jpg: 384x640 1 pedestrian, 5.6ms
# image 4/3400 /content/BDD_YOLO/images/val/b1ceb32e-3f481b43.jpg: 384x640 (no detections), 5.5ms
# image 5/3400 /content/BDD_YOLO/images/val/b1ceb32e-51852abe.jpg: 384x640 1 pedestrian, 5.5ms
# image 6/3400 /content/BDD_YOLO/images/val/b1ceb32e-a106591d.jpg: 384x640 (no detections), 5.9ms
# image 7/3400 /content/BDD_YOLO/images/val/b1d0a191-03dcecc2.jpg: 384x640 9 pedestrians, 5.5ms
# image 8/3400 /content/BDD_YOLO/images/val/b1d0a191-06deb55d.jpg: 384x640 8 pedestrians, 5.4ms
# ...

# %%
# !ls /content/runs/detect/predict
# Out:
# b1c66a42-6f7d68ca.jpg  b9d12c48-d855b440.jpg  c1f39934-7fc50bd1.jpg
# b1ca2e5d-84cf9134.jpg  b9d34460-2c3b1ab3.jpg  c1f39934-d26d7dd2.jpg
# b1cd1e94-549d0bfe.jpg  b9d34460-68942f09.jpg  c1f4b883-84444018.jpg
# b1ceb32e-3f481b43.jpg  b9d34460-d648a4c1.jpg  c1f65250-7a0e931b.jpg
# b1ceb32e-51852abe.jpg  b9d47fe7-858753e0.jpg  c1f7104e-b64ae3b2.jpg
# b1ceb32e-a106591d.jpg  b9d9e358-7dadc57c.jpg  c1f7cec6-549a06ac.jpg
# b1d0a191-03dcecc2.jpg  b9db357e-cd30a8ae.jpg  c1f8d9b3-c6dae792.jpg
# b1d0a191-06deb55d.jpg  b9de552a-0e2a01b8.jpg  c1f8d9b3-e7a69cc0.jpg
# b1d0a191-28f0e779.jpg  b9df54a4-314e9e5e.jpg  c1f9f357-0ea2a4a9.jpg
# b1d0a191-2ed2269e.jpg  b9df54a4-66f58812.jpg  c1fa7950-fbc6ec93.jpg
# b1d0a191-5490450b.jpg  b9df54a4-8203d67b.jpg  c1fa81f4-43a87286.jpg
# b1d0a191-65deaeef.jpg  b9df54a4-84660617.jpg  c1fcdfd1-b34ce63c.jpg
# b1d0a191-de8948f6.jpg  b9e1e369-72bfc6bb.jpg  c1fdd182-28e0d6aa.jpg
# b1d10d08-da110fcb.jpg  b9e4cb3d-975f9d1d.jpg  c2021f20-46a5823b.jpg
# ...

# %%
# !mkdir -p /content/drive/MyDrive/ADAS_PREDICTIONS
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/ADAS_PREDICTIONS/

# %%
# !zip -r ADAS_EXPORT.zip \
/content/drive/MyDrive/ADAS_MODELS \
/content/drive/MyDrive/ADAS_RUN_RESULTS \
/content/drive/MyDrive/ADAS_PREDICTIONS
# Out:
#   adding: content/drive/MyDrive/ADAS_MODELS/ (stored 0%)
#   adding: content/drive/MyDrive/ADAS_MODELS/best.pt (deflated 9%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/ (stored 0%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/ (stored 0%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/weights/ (stored 0%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/weights/last.pt (deflated 9%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/weights/best.pt (deflated 9%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/args.yaml (deflated 52%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/labels.jpg (deflated 36%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/train_batch0.jpg (deflated 6%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/train_batch1.jpg (deflated 5%)
#   adding: content/drive/MyDrive/ADAS_RUN_RESULTS/train2/train_batch2.jpg (deflated 4%)
# ...

# %%
from google.colab import files
files.download("ADAS_EXPORT.zip")
